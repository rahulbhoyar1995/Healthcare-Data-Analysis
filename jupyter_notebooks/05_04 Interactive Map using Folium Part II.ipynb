# %% [markdown]
# ##Interactive Map for Public Health Facilities Geolocation Demo Dataset using Folium Part I

# %%
import pandas as pd
import folium

# %%
df_geo = pd.read_csv('/content/demo_health_facilities_geo_data.csv')
df_geo
# Out:
#     Facility Type   Latitude  Longitude
# 0        Hospital   5.593051   3.697007
# 1        Hospital  10.017569   9.921846
# 2        Hospital   7.568808  11.178651
# 3        Hospital  11.574567  12.594135
# 4        Hospital   6.093634   9.334975
# ..            ...        ...        ...
# 762      Pharmacy  11.844224   9.831699
# 763      Pharmacy   8.228317   8.502529
# 764      Pharmacy   8.162100   4.821424
# 765      Pharmacy   7.568452   8.388384
# 766      Pharmacy   4.330299  10.229440
#
# [767 rows x 3 columns]

# %%
df_geo['Facility Type'].nunique()
# Out:
# 4

# %%
df_geo['Facility Type'].unique()
# Out:
# array(['Hospital', 'Primary Care Center', 'Specialized Healthcare Center',
#        'Pharmacy'], dtype=object)

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'][0]])
for index,row in df_geo.iterrows():
    folium.Marker([row['Latitude'],row['Longitude']], popup=row['Facility Type']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9277680099a5e0dd7ea969c5c28d727 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9277680099a5e0dd7ea969c5c28d727&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9277680099a5e0dd7ea969c5c28d727 = L.map(
#                 &quot;map_d9277680099a5e0dd7ea969c5c28d727&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f26d8fb52ff620ac1d45bf7c22db71ee = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9277680099a5e0dd7ea969c5c28d727);
#
#
#             var marker_942215f53ed81cd494f2a3e7a061289c = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_d9277680099a5e0dd7ea969c5c28d727);
#
#
#         var popup_03563e25c10b7d11f8eea8d28aca8baa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_836532f873a0d54f9b9e8d478acfee4e = $(`&lt;div id=&quot;html_836532f873a0d54f9b9e8d478acfee4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_03563e25c10b7d11f8eea8d28aca8baa.setContent(html_836532f873a0d54f9b9e8d478acfee4e);
#
#
#
#         marker_942215f53ed81cd494f2a3e7a061289c.bindPopup(popup_03563e25c10b7d11f8eea8d28aca8baa)
#         ;
#
#
#
#
#             var marker_1b679ccc2ac5846918e876650644ecd9 = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_d9277680099a5e0dd7ea969c5c28d727);
#
#
#         var popup_7e89376748b8401f2788a941ed00c275 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_43ac9a9b67b6ad0009bfc1fb14257319 = $(`&lt;div id=&quot;html_43ac9a9b67b6ad0009bfc1fb14257319&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_7e89376748b8401f2788a941ed00c275.setContent(html_43ac9a9b67b6ad0009bfc1fb14257319);
#
#
#
#         marker_1b679ccc2ac5846918e876650644ecd9.bindPopup(popup_7e89376748b8401f2788a941ed00c275)
#         ;
#
#
#
#
#             var marker_bd62300331dcea95584c4c11a4f35348 = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_d9277680099a5e0dd7ea969c5c28d727);
#
#
#         var popup_1e44459d660757ec49a65e197c99aa86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0d7659abfe915f69678b7fa9abadcc82 = $(`&lt;div id=&quot;html_0d7659abfe915f69678b7fa9abadcc82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_1e44459d660757ec49a65e197c99aa86.setContent(html_0d7659abfe915f69678b7fa9abadcc82);
#
#
#
#         marker_bd62300331dcea95584c4c11a4f35348.bindPopup(popup_1e44459d660757ec49a65e197c99aa86)
#         ;
#
#
#
#
#             var marker_61f4093703ed8f5c518ef65f6e15db5e = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_d9277680099a5e0dd7ea969c5c28d727);
#
#
#         var popup_814c2abee073996b3ae55d10ff4e1eae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5c4b3b60cb98e820df6fb0d9a75b434c = $(`&lt;div id=&quot;html_5c4b3b60cb98e820df6fb0d9a75b434c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_814c2abee073996b3ae55d10ff4e1eae.setContent(html_5c4b3b60cb98e820df6fb0d9a75b434c);
#
#
#
#         marker_61f4093703ed8f5c518ef65f6e15db5e.bindPopup(popup_814c2abee073996b3ae55d10ff4e1eae)
#         ;
#
#
#
#
#             var marker_5fb5aeacfc30f4b5f686616734974f78 = L.marker(
#                 [6.093634303928882, 9.334974717175706],
#                 {}
#             ).addTo(map_d9277680099a5e0dd7ea969c5c28d727);
#
#
#         var popup_8cac6dca3eb1d9a02ea6513616be6474 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a59748ca99aa0f3aa086d6516b95c138 = $(`&lt;div id=&quot;html_a59748ca99aa0f3aa086d6516b95c138&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_8cac6dca3eb1d9a02ea6513616be6474.setContent(html_a59748ca99aa0f3aa086d6516b95c138);
#
#
#
#         marker_5fb5aeacfc30f4b5f686616734974f78.bindPopup(popup_8cac6dca3eb1d9a02ea6513616be6474)
#         ;
#
#
#
#
#             var marker_6251d9b9235eb34d4d8a44b8a4

# %%
facility_color_mapping = {'Hospital':'red', 'Primary Care Center':'blue','Specialized Healthcare Center':'green','Pharmacy':'purple'}

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'][0]])
for index, row in df_geo.iterrows():
    facility_type = row['Facility Type']
    if facility_type in facility_color_mapping:
        color = facility_color_mapping[facility_type]
    else:
        color = 'gray'
    folium.Marker(location=[row['Latitude'],row['Longitude']],popup=row['Facility Type'], icon=folium.Icon(color=color)).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d5f1d3c57a9e25b2368680f64ea4711 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d5f1d3c57a9e25b2368680f64ea4711&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d5f1d3c57a9e25b2368680f64ea4711 = L.map(
#                 &quot;map_2d5f1d3c57a9e25b2368680f64ea4711&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44152da0250a6892b36bc68a277752ed = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2d5f1d3c57a9e25b2368680f64ea4711);
#
#
#             var marker_27f1112ff10019df58cf33af93b7de95 = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_2d5f1d3c57a9e25b2368680f64ea4711);
#
#
#             var icon_c8d1ac4615970f9aa8a837acecb008cc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_27f1112ff10019df58cf33af93b7de95.setIcon(icon_c8d1ac4615970f9aa8a837acecb008cc);
#
#
#         var popup_0e49b459007a90c4d3d7ff727d12aff7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a818466c5f44b08d15bb3bba9f9ced5f = $(`&lt;div id=&quot;html_a818466c5f44b08d15bb3bba9f9ced5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_0e49b459007a90c4d3d7ff727d12aff7.setContent(html_a818466c5f44b08d15bb3bba9f9ced5f);
#
#
#
#         marker_27f1112ff10019df58cf33af93b7de95.bindPopup(popup_0e49b459007a90c4d3d7ff727d12aff7)
#         ;
#
#
#
#
#             var marker_1dfa61548c97c463b7d4d555ad84da21 = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_2d5f1d3c57a9e25b2368680f64ea4711);
#
#
#             var icon_94195f458f20aed4bb192f03e713de37 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1dfa61548c97c463b7d4d555ad84da21.setIcon(icon_94195f458f20aed4bb192f03e713de37);
#
#
#         var popup_deb388490ab66812986468fe865fe499 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0e0ad6c6f6c2afc3566eeffeddb21f01 = $(`&lt;div id=&quot;html_0e0ad6c6f6c2afc3566eeffeddb21f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_deb388490ab66812986468fe865fe499.setContent(html_0e0ad6c6f6c2afc3566eeffeddb21f01);
#
#
#
#         marker_1dfa61548c97c463b7d4d555ad84da21.bindPopup(popup_deb388490ab66812986468fe865fe499)
#         ;
#
#
#
#
#             var marker_90c09de19eb2e68f8033535c4c2cf685 = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_2d5f1d3c57a9e25b2368680f64ea4711);
#
#
#             var icon_a6fcdd090bc1a9ebcdc7df5e1e4cfb0e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_90c09de19eb2e68f8033535c4c2cf685.setIcon(icon_a6fcdd090bc1a9ebcdc7df5e1e4cfb0e);
#
#
#         var popup_e56bcbbd0863ba6cd54c0901528c7b32 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f30de8c0cf8c6c2f227a8c6fa43ac37 = $(`&lt;div id=&quot;html_4f30de8c0cf8c6c2f227a8c6fa43ac37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_e56bcbbd0863ba6cd54c0901528c7b32.setContent(html_4f30de8c0cf8c6c2f227a8c6fa43ac37);
#
#
#
#         marker_90c09de19eb2e68f8033535c4c2cf685.bindPopup(popup_e56bcbbd0863ba6cd54c0901528c7b32)
#         ;
#
#
#
#
#             var marker_0c2864b45f05bb58a4910e8c5c5e8017 = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_2d5f1d3c57a9e25b2368680f64ea4711);
#
#
#             var icon_50d0c3d633dd2725abd0fe9ff79d36d8 = L.AwesomeMarkers.icon(
#                 {&quot;extra

# %% [markdown]
# ##Interactive Map for Public Health Facilities Geolocation Demo Dataset using Folium Part II

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'].iloc[0]])
facility_types_to_visualize = ['Hospital']
filtered_df = df_geo[df_geo['Facility Type'].isin(facility_types_to_visualize)]

for index, row in filtered_df.iterrows():
    facility_type = row['Facility Type']
    color = facility_color_mapping.get(facility_type,'gray')
    folium.Marker(location=[row['Latitude'],row['Longitude']], popup=row['Facility Type'], icon=folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5cee1f62aed852164d3df1526be6ab4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5cee1f62aed852164d3df1526be6ab4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5cee1f62aed852164d3df1526be6ab4 = L.map(
#                 &quot;map_b5cee1f62aed852164d3df1526be6ab4&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_992dc00e3a990d06f1f1524b9615159a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5cee1f62aed852164d3df1526be6ab4);
#
#
#             var marker_7578f47530988a2c33c7157b557f2e30 = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_b5cee1f62aed852164d3df1526be6ab4);
#
#
#             var icon_f0febd35375116a5d59e770df65167e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7578f47530988a2c33c7157b557f2e30.setIcon(icon_f0febd35375116a5d59e770df65167e5);
#
#
#         var popup_62ae7a46c67ffd89a2ed6b0aecd90c7c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71ef522c9bf04130808d6540ce6a4b2f = $(`&lt;div id=&quot;html_71ef522c9bf04130808d6540ce6a4b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_62ae7a46c67ffd89a2ed6b0aecd90c7c.setContent(html_71ef522c9bf04130808d6540ce6a4b2f);
#
#
#
#         marker_7578f47530988a2c33c7157b557f2e30.bindPopup(popup_62ae7a46c67ffd89a2ed6b0aecd90c7c)
#         ;
#
#
#
#
#             var marker_f3acd976d2d6e07dcd472402cbabed69 = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_b5cee1f62aed852164d3df1526be6ab4);
#
#
#             var icon_d87090c32a10750ab2ce5df03eb18124 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3acd976d2d6e07dcd472402cbabed69.setIcon(icon_d87090c32a10750ab2ce5df03eb18124);
#
#
#         var popup_b48482ae06ce556d6b78112909f07b85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f8d47d46531b8b202efc56126e45e61 = $(`&lt;div id=&quot;html_5f8d47d46531b8b202efc56126e45e61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_b48482ae06ce556d6b78112909f07b85.setContent(html_5f8d47d46531b8b202efc56126e45e61);
#
#
#
#         marker_f3acd976d2d6e07dcd472402cbabed69.bindPopup(popup_b48482ae06ce556d6b78112909f07b85)
#         ;
#
#
#
#
#             var marker_150e696bc37039238113f124bed956af = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_b5cee1f62aed852164d3df1526be6ab4);
#
#
#             var icon_b0284907720310f926f39f4563b35003 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_150e696bc37039238113f124bed956af.setIcon(icon_b0284907720310f926f39f4563b35003);
#
#
#         var popup_8f01a03622e991c5a613d98f07616f86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4bcfcb0df2cdb3a8a9a674d3083c18bb = $(`&lt;div id=&quot;html_4bcfcb0df2cdb3a8a9a674d3083c18bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_8f01a03622e991c5a613d98f07616f86.setContent(html_4bcfcb0df2cdb3a8a9a674d3083c18bb);
#
#
#
#         marker_150e696bc37039238113f124bed956af.bindPopup(popup_8f01a03622e991c5a613d98f07616f86)
#         ;
#
#
#
#
#             var marker_f8c4ead6415c66d47f3868eb2fc162bd = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_b5cee1f62aed852164d3df1526be6ab4);
#
#
#             var icon_b76f55328df6814ea2be2abfb017e7f2 = L.AwesomeMarkers.icon(
#                 {&quot;extra
