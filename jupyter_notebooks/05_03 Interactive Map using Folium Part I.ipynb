# %%
import pandas as pd
import folium

# %%
df_geo = pd.read_csv('/content/demo_health_facilities_geo_data.csv')
df_geo
# Out:
#     Facility Type   Latitude  Longitude
# 0        Hospital   5.593051   3.697007
# 1        Hospital  10.017569   9.921846
# 2        Hospital   7.568808  11.178651
# 3        Hospital  11.574567  12.594135
# 4        Hospital   6.093634   9.334975
# ..            ...        ...        ...
# 762      Pharmacy  11.844224   9.831699
# 763      Pharmacy   8.228317   8.502529
# 764      Pharmacy   8.162100   4.821424
# 765      Pharmacy   7.568452   8.388384
# 766      Pharmacy   4.330299  10.229440
#
# [767 rows x 3 columns]

# %%
df_geo['Facility Type'].nunique()
# Out:
# 4

# %%
df_geo['Facility Type'].unique()
# Out:
# array(['Hospital', 'Primary Care Center', 'Specialized Healthcare Center',
#        'Pharmacy'], dtype=object)

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'][0]])
for index,row in df_geo.iterrows():
    folium.Marker([row['Latitude'],row['Longitude']], popup=row['Facility Type']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8331045b8242c286860d4ffbbcc59141 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8331045b8242c286860d4ffbbcc59141&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8331045b8242c286860d4ffbbcc59141 = L.map(
#                 &quot;map_8331045b8242c286860d4ffbbcc59141&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99469b8399496e3454380cf3e40ae28c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8331045b8242c286860d4ffbbcc59141);
#
#
#             var marker_d3099a2cbc89fed5314e56eadaac746f = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_8331045b8242c286860d4ffbbcc59141);
#
#
#         var popup_6fc65e3f3234762f4fb15b7915aa4430 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db7e5d77202518a375256f47c598e0ca = $(`&lt;div id=&quot;html_db7e5d77202518a375256f47c598e0ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_6fc65e3f3234762f4fb15b7915aa4430.setContent(html_db7e5d77202518a375256f47c598e0ca);
#
#
#
#         marker_d3099a2cbc89fed5314e56eadaac746f.bindPopup(popup_6fc65e3f3234762f4fb15b7915aa4430)
#         ;
#
#
#
#
#             var marker_08306880b0ddbeb40439c3ce1229737f = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_8331045b8242c286860d4ffbbcc59141);
#
#
#         var popup_2eba70e223ef92ac8b5ea70ab61110e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a25231975b2f1d5785c592944b078cb5 = $(`&lt;div id=&quot;html_a25231975b2f1d5785c592944b078cb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_2eba70e223ef92ac8b5ea70ab61110e2.setContent(html_a25231975b2f1d5785c592944b078cb5);
#
#
#
#         marker_08306880b0ddbeb40439c3ce1229737f.bindPopup(popup_2eba70e223ef92ac8b5ea70ab61110e2)
#         ;
#
#
#
#
#             var marker_67a5e51f6ab225c1f121bc1b2a345adc = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_8331045b8242c286860d4ffbbcc59141);
#
#
#         var popup_cf125238f82fdd17f17512fc2d536f2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9cefe7f46d11938b48c280a1b4ad625f = $(`&lt;div id=&quot;html_9cefe7f46d11938b48c280a1b4ad625f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_cf125238f82fdd17f17512fc2d536f2f.setContent(html_9cefe7f46d11938b48c280a1b4ad625f);
#
#
#
#         marker_67a5e51f6ab225c1f121bc1b2a345adc.bindPopup(popup_cf125238f82fdd17f17512fc2d536f2f)
#         ;
#
#
#
#
#             var marker_703874bab16d3685fae9197c817bbd61 = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_8331045b8242c286860d4ffbbcc59141);
#
#
#         var popup_b0ddcecc7e8f14a12499d5da6bee3d5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a8d3a497ab4a9119f105e75e1c47ccf = $(`&lt;div id=&quot;html_7a8d3a497ab4a9119f105e75e1c47ccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_b0ddcecc7e8f14a12499d5da6bee3d5e.setContent(html_7a8d3a497ab4a9119f105e75e1c47ccf);
#
#
#
#         marker_703874bab16d3685fae9197c817bbd61.bindPopup(popup_b0ddcecc7e8f14a12499d5da6bee3d5e)
#         ;
#
#
#
#
#             var marker_6d9f7ee2415c0a48a806f5126f89c1eb = L.marker(
#                 [6.093634303928882, 9.334974717175706],
#                 {}
#             ).addTo(map_8331045b8242c286860d4ffbbcc59141);
#
#
#         var popup_7f661506ff32700feb4af0f6aacae9e3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_255c2ba628d4a2da3bf53d28ce9c07a0 = $(`&lt;div id=&quot;html_255c2ba628d4a2da3bf53d28ce9c07a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_7f661506ff32700feb4af0f6aacae9e3.setContent(html_255c2ba628d4a2da3bf53d28ce9c07a0);
#
#
#
#         marker_6d9f7ee2415c0a48a806f5126f89c1eb.bindPopup(popup_7f661506ff32700feb4af0f6aacae9e3)
#         ;
#
#
#
#
#             var marker_a9de250976a26631e4b8c5797a

# %%
facility_color_mapping = {'Hospital':'red', 'Primary Care Center':'blue','Specialized Healthcare Center':'green','Pharmacy':'purple'}

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'][0]])
for index, row in df_geo.iterrows():
    facility_type = row['Facility Type']
    if facility_type in facility_color_mapping:
        color = facility_color_mapping[facility_type]
    else:
        color = 'gray'
    folium.Marker(location=[row['Latitude'],row['Longitude']],popup=row['Facility Type'], icon=folium.Icon(color=color)).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_500d2719a211d446214518a1feeeff6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_500d2719a211d446214518a1feeeff6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_500d2719a211d446214518a1feeeff6e = L.map(
#                 &quot;map_500d2719a211d446214518a1feeeff6e&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55fd48fab0b7cff0950b975ea6fc9c36 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_500d2719a211d446214518a1feeeff6e);
#
#
#             var marker_f5260f1b1b1aacee794a5be23e1a085c = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_500d2719a211d446214518a1feeeff6e);
#
#
#             var icon_d0c598a7eca52fbf6c4f26086b22e4f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f5260f1b1b1aacee794a5be23e1a085c.setIcon(icon_d0c598a7eca52fbf6c4f26086b22e4f5);
#
#
#         var popup_812e60cf1bca0d3d08ae798f6a7943d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_96ab17ceb68846b8ceda7d00f3a626ca = $(`&lt;div id=&quot;html_96ab17ceb68846b8ceda7d00f3a626ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_812e60cf1bca0d3d08ae798f6a7943d0.setContent(html_96ab17ceb68846b8ceda7d00f3a626ca);
#
#
#
#         marker_f5260f1b1b1aacee794a5be23e1a085c.bindPopup(popup_812e60cf1bca0d3d08ae798f6a7943d0)
#         ;
#
#
#
#
#             var marker_9c06d48e50e135d925f23d7b788f4d02 = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_500d2719a211d446214518a1feeeff6e);
#
#
#             var icon_0200f4703b5b3d5a62e2a31c31d9c3ca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9c06d48e50e135d925f23d7b788f4d02.setIcon(icon_0200f4703b5b3d5a62e2a31c31d9c3ca);
#
#
#         var popup_a2877871575fc8a6a6ad32fa6885ce61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4c7d461065bb25073b12717d289b03b = $(`&lt;div id=&quot;html_f4c7d461065bb25073b12717d289b03b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_a2877871575fc8a6a6ad32fa6885ce61.setContent(html_f4c7d461065bb25073b12717d289b03b);
#
#
#
#         marker_9c06d48e50e135d925f23d7b788f4d02.bindPopup(popup_a2877871575fc8a6a6ad32fa6885ce61)
#         ;
#
#
#
#
#             var marker_4dbc7be8b1b92d57669c9b89b459c458 = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_500d2719a211d446214518a1feeeff6e);
#
#
#             var icon_d0b7cf31862d940ef95ee01f2ad17c73 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4dbc7be8b1b92d57669c9b89b459c458.setIcon(icon_d0b7cf31862d940ef95ee01f2ad17c73);
#
#
#         var popup_70118848e9b363504552ba84933b1c4f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cb38d231fcd415d0d93afe984d88a180 = $(`&lt;div id=&quot;html_cb38d231fcd415d0d93afe984d88a180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_70118848e9b363504552ba84933b1c4f.setContent(html_cb38d231fcd415d0d93afe984d88a180);
#
#
#
#         marker_4dbc7be8b1b92d57669c9b89b459c458.bindPopup(popup_70118848e9b363504552ba84933b1c4f)
#         ;
#
#
#
#
#             var marker_53b27b9622e439a918d3c750080275da = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_500d2719a211d446214518a1feeeff6e);
#
#
#             var icon_5bf97ef6c38d5e79f9ceae91af7e7901 = L.AwesomeMarkers.icon(
#                 {&quot;extra
