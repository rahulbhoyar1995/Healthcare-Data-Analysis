# %% [markdown]
# ##Practical data manipulation and  wrangling using pandas Part I

# %%
import pandas as pd

# %%
pd.read_csv("/content/1000_Generic_Medication_Names.txt")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-2-e156c37729e8> in <cell line: 1>()
# ----> 1 pd.read_csv("/content/1000_Generic_Medication_Names.txt")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
pd.read_csv("/content/1000_Generic_Medication_Names.txt",sep='\t')
# Out:
#           1. Acetaminophen Tablet (500 mg) - Analgesic
# 0    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 1    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 2    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 3        5. Morphine Tablet (15 mg) - Opioid Analgesic
# 4        6. Oxycodone Tablet (5 mg) - Opioid Analgesic
# ..                                                 ...
# 994  996. Alprostadil Urethral Suppository (250 mcg...
# 995  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 996  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 997   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 998  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
# [999 rows x 1 columns]

# %%
pd.read_csv("/content/1000_Generic_Medication_Names.txt",sep='\t',header=None)
# Out:
#                                                      0
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
# [1000 rows x 1 columns]

# %%
df_med = pd.read_csv("/content/1000_Generic_Medication_Names.txt",sep='\t',header=None)
df_med
# Out:
#                                                      0
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
# [1000 rows x 1 columns]

# %%
df_med[0][0]
# Out:
# '1. Acetaminophen Tablet (500 mg) - Analgesic'

# %%
type(df_med[0][0])
# Out:
# str

# %%
df_med[0][0].split(".")
# Out:
# ['1', ' Acetaminophen Tablet (500 mg) - Analgesic']

# %%
df_med[0][0].split("-")
# Out:
# ['1. Acetaminophen Tablet (500 mg) ', ' Analgesic']

# %%
type(df_med[0][0].split("-"))
# Out:
# list

# %%
df_med[0][0].split("-")[0]
# Out:
# '1. Acetaminophen Tablet (500 mg) '

# %%
df_med[0][0].split("-")[1]
# Out:
# ' Analgesic'

# %%
df_med['Med_class'] = df_med[0].apply(lambda x : x.split("-")[1])
df_med
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                            Med_class
# 0                          Analgesic
# 1                  Nonsteroidal Anti
# 2     Platelet Aggregation Inhibitor
# 3                  Nonsteroidal Anti
# 4                   Opioid Analgesic
# ..                               ...
# ...

# %%
df_med[0][996]
# Out:
# '997. Phentolamine Injection (1 mg/mL) - Alpha-Blocker'

# %%
df_med['Med_class'][996]
# Out:
# ' Alpha'

# %%
df_med[0][998]
# Out:
# '999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker'

# %%
df_med[0][999]
# Out:
# '1000. L-Arginine Tablet (500 mg) - Amino Acid Supplement'

# %%
df_med[0][999].split(".")
# Out:
# ['1000', ' L-Arginine Tablet (500 mg) - Amino Acid Supplement']

# %%
df_med[0][999].split(".")[1]
# Out:
# ' L-Arginine Tablet (500 mg) - Amino Acid Supplement'

# %%
df_med[0][999].split(".")[1].split("-")
# Out:
# [' L', 'Arginine Tablet (500 mg) ', ' Amino Acid Supplement']

# %%
df_med[0][999].split(".")[1].split("-")[0]
# Out:
# ' L'

# %%
df_med[0][998].split(".")
# Out:
# ['999', ' Yohimbine Tablet (5', '4 mg) - Alpha-2 Blocker']

# %%
df_med[0][998].split(".",maxsplit=1)
# Out:
# ['999', ' Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker']

# %%
df_med["Med_name"] = df_med[0].apply(lambda x: x.split(".", maxsplit=1)[1].split("-")[0])
df_med
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                            Med_class  \
# 0                          Analgesic
# 1                  Nonsteroidal Anti
# 2     Platelet Aggregation Inhibitor
# 3                  Nonsteroidal Anti
# 4                   Opioid Analgesic
# ..                               ...
# ...

# %% [markdown]
# ##Practical data manipulation and  wrangling using pandas Part II

# %%
df_med[["combined","Med_class_2"]] = df_med[0].str.split("-",1,expand=True)
df_med
# Out:
# <ipython-input-25-90514d1612d7>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df_med[["combined","Med_class_2"]] = df_med[0].str.split("-",1,expand=True)
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                            Med_class  \
# ...

# %%
df_med_2 = df_med[["Med_name","Med_class_2"]]
df_med_2
# Out:
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
# 999                                             L
#
#                                           Med_class_2
# 0                                           Analgesic
# 1                 Nonsteroidal Anti-Inflammatory Drug
# 2                      Platelet Aggregation Inhibitor
# 3                 Nonsteroidal Anti-Inflammatory Drug
# 4                                    Opioid Analgesic
# ...

# %%
df_med_2.rename(columns={"Med_class_2":"Medication_class"}, inplace=True)
df_med_2
# Out:
# <ipython-input-36-c62618528f89>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_med_2.rename(columns={"Med_class_2":"Medication_class"}, inplace=True)
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
# 999                                             L
#
# ...

# %%
df_med_2
# Out:
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
# 999                                             L
#
#                                      Medication_class
# 0                                           Analgesic
# 1                 Nonsteroidal Anti-Inflammatory Drug
# 2                      Platelet Aggregation Inhibitor
# 3                 Nonsteroidal Anti-Inflammatory Drug
# 4                                    Opioid Analgesic
# ...

# %%
df_med_2.drop([999])
# Out:
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 994                     Vardenafil Tablet (5 mg)
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
#
#                          Medication_class
# 0                               Analgesic
# 1     Nonsteroidal Anti-Inflammatory Drug
# 2          Platelet Aggregation Inhibitor
# 3     Nonsteroidal Anti-Inflammatory Drug
# 4                        Opioid Analgesic
# ..                                    ...
# 994    Phosphodiesterase Type 5 Inhibitor
# ...

# %%
df_med_2
# Out:
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
# 999                                             L
#
#                                      Medication_class
# 0                                           Analgesic
# 1                 Nonsteroidal Anti-Inflammatory Drug
# 2                      Platelet Aggregation Inhibitor
# 3                 Nonsteroidal Anti-Inflammatory Drug
# 4                                    Opioid Analgesic
# ...

# %%
df_med_2 = df_med_2.drop([999])
df_med_2
# Out:
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 994                     Vardenafil Tablet (5 mg)
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
#
#                          Medication_class
# 0                               Analgesic
# 1     Nonsteroidal Anti-Inflammatory Drug
# 2          Platelet Aggregation Inhibitor
# 3     Nonsteroidal Anti-Inflammatory Drug
# 4                        Opioid Analgesic
# ..                                    ...
# 994    Phosphodiesterase Type 5 Inhibitor
# ...

# %%
df_med_2.to_csv("Med_name_and_class.csv", index=False)

# %%
pd.read_csv("/content/Med_name_and_class.csv")
# Out:
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 994                     Vardenafil Tablet (5 mg)
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
#
#                          Medication_class
# 0                               Analgesic
# 1     Nonsteroidal Anti-Inflammatory Drug
# 2          Platelet Aggregation Inhibitor
# 3     Nonsteroidal Anti-Inflammatory Drug
# 4                        Opioid Analgesic
# ..                                    ...
# 994    Phosphodiesterase Type 5 Inhibitor
# ...

# %%
df_med_3 = df_med.copy()
df_med_3
# Out:
#                                                      0  \
# 0         1. Acetaminophen Tablet (500 mg) - Analgesic
# 1    2. Ibuprofen Tablet (200 mg) - Nonsteroidal An...
# 2    3. Aspirin Tablet (81 mg) - Platelet Aggregati...
# 3    4. Naproxen Tablet (250 mg) - Nonsteroidal Ant...
# 4        5. Morphine Tablet (15 mg) - Opioid Analgesic
# ..                                                 ...
# 995  996. Alprostadil Urethral Suppository (250 mcg...
# 996  997. Phentolamine Injection (1 mg/mL) - Alpha-...
# 997  998. Papaverine Injection (30 mg/mL) - Vasodil...
# 998   999. Yohimbine Tablet (5.4 mg) - Alpha-2 Blocker
# 999  1000. L-Arginine Tablet (500 mg) - Amino Acid ...
#
#                            Med_class  \
# 0                          Analgesic
# 1                  Nonsteroidal Anti
# 2     Platelet Aggregation Inhibitor
# 3                  Nonsteroidal Anti
# 4                   Opioid Analgesic
# ..                               ...
# ...

# %%
df_med_3 = df_med_3.drop(columns=[0,"Med_class","combined"])
df_med_3
# Out:
#                                          Med_name  \
# 0                  Acetaminophen Tablet (500 mg)
# 1                      Ibuprofen Tablet (200 mg)
# 2                         Aspirin Tablet (81 mg)
# 3                       Naproxen Tablet (250 mg)
# 4                        Morphine Tablet (15 mg)
# ..                                            ...
# 995   Alprostadil Urethral Suppository (250 mcg)
# 996             Phentolamine Injection (1 mg/mL)
# 997              Papaverine Injection (30 mg/mL)
# 998                    Yohimbine Tablet (5.4 mg)
# 999                                             L
#
#                                           Med_class_2
# 0                                           Analgesic
# 1                 Nonsteroidal Anti-Inflammatory Drug
# 2                      Platelet Aggregation Inhibitor
# 3                 Nonsteroidal Anti-Inflammatory Drug
# 4                                    Opioid Analgesic
# ...
