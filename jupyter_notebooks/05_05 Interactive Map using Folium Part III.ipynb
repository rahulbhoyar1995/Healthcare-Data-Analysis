# %% [markdown]
# ##Interactive Map for Public Health Facilities Geolocation Demo Dataset using Folium Part I

# %%
import pandas as pd
import folium

# %%
df_geo = pd.read_csv('/content/demo_health_facilities_geo_data.csv')
df_geo
# Out:
#     Facility Type   Latitude  Longitude
# 0        Hospital   5.593051   3.697007
# 1        Hospital  10.017569   9.921846
# 2        Hospital   7.568808  11.178651
# 3        Hospital  11.574567  12.594135
# 4        Hospital   6.093634   9.334975
# ..            ...        ...        ...
# 762      Pharmacy  11.844224   9.831699
# 763      Pharmacy   8.228317   8.502529
# 764      Pharmacy   8.162100   4.821424
# 765      Pharmacy   7.568452   8.388384
# 766      Pharmacy   4.330299  10.229440
#
# [767 rows x 3 columns]

# %%
df_geo['Facility Type'].nunique()
# Out:
# 4

# %%
df_geo['Facility Type'].unique()
# Out:
# array(['Hospital', 'Primary Care Center', 'Specialized Healthcare Center',
#        'Pharmacy'], dtype=object)

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'][0]])
for index,row in df_geo.iterrows():
    folium.Marker([row['Latitude'],row['Longitude']], popup=row['Facility Type']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b7ca6ce466e09a29a6aeb514e4095f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b7ca6ce466e09a29a6aeb514e4095f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b7ca6ce466e09a29a6aeb514e4095f1 = L.map(
#                 &quot;map_5b7ca6ce466e09a29a6aeb514e4095f1&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd87385d29499cfdc03822e881d3ee00 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5b7ca6ce466e09a29a6aeb514e4095f1);
#
#
#             var marker_05c2849ecec9193f6d3d7b11cdd6c9b0 = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_5b7ca6ce466e09a29a6aeb514e4095f1);
#
#
#         var popup_5a8a820b958b6515eee3661d807d26e4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b363c6858b164861684a437756ef7e9 = $(`&lt;div id=&quot;html_7b363c6858b164861684a437756ef7e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_5a8a820b958b6515eee3661d807d26e4.setContent(html_7b363c6858b164861684a437756ef7e9);
#
#
#
#         marker_05c2849ecec9193f6d3d7b11cdd6c9b0.bindPopup(popup_5a8a820b958b6515eee3661d807d26e4)
#         ;
#
#
#
#
#             var marker_abe2c2f69060c4bd0acaf52f6e5c9dce = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_5b7ca6ce466e09a29a6aeb514e4095f1);
#
#
#         var popup_8064a94843b1fde314636e08c811c532 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04e9d21dad61c4e4964ecbe513612a5a = $(`&lt;div id=&quot;html_04e9d21dad61c4e4964ecbe513612a5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_8064a94843b1fde314636e08c811c532.setContent(html_04e9d21dad61c4e4964ecbe513612a5a);
#
#
#
#         marker_abe2c2f69060c4bd0acaf52f6e5c9dce.bindPopup(popup_8064a94843b1fde314636e08c811c532)
#         ;
#
#
#
#
#             var marker_80ba615a39b48ad56b45a34ea3726a17 = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_5b7ca6ce466e09a29a6aeb514e4095f1);
#
#
#         var popup_76f859edb98fbf5ad4a11d25fb2e895b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dc2ae132d222ace052b5cbe04c759ac7 = $(`&lt;div id=&quot;html_dc2ae132d222ace052b5cbe04c759ac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_76f859edb98fbf5ad4a11d25fb2e895b.setContent(html_dc2ae132d222ace052b5cbe04c759ac7);
#
#
#
#         marker_80ba615a39b48ad56b45a34ea3726a17.bindPopup(popup_76f859edb98fbf5ad4a11d25fb2e895b)
#         ;
#
#
#
#
#             var marker_19b0ca45e81078854c913dcab930118b = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_5b7ca6ce466e09a29a6aeb514e4095f1);
#
#
#         var popup_64a3ff2a3cd99235c9fd6d6d3a90b9a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c4f62a5d029b14fc7904ffbadc50d94 = $(`&lt;div id=&quot;html_0c4f62a5d029b14fc7904ffbadc50d94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_64a3ff2a3cd99235c9fd6d6d3a90b9a2.setContent(html_0c4f62a5d029b14fc7904ffbadc50d94);
#
#
#
#         marker_19b0ca45e81078854c913dcab930118b.bindPopup(popup_64a3ff2a3cd99235c9fd6d6d3a90b9a2)
#         ;
#
#
#
#
#             var marker_46fe4cda2b5a72b94a1e1f1ee6dd93c5 = L.marker(
#                 [6.093634303928882, 9.334974717175706],
#                 {}
#             ).addTo(map_5b7ca6ce466e09a29a6aeb514e4095f1);
#
#
#         var popup_0c749ed870488670be1c731c37e32906 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf9a7ac8b840a7cee10136603f77cc16 = $(`&lt;div id=&quot;html_cf9a7ac8b840a7cee10136603f77cc16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_0c749ed870488670be1c731c37e32906.setContent(html_cf9a7ac8b840a7cee10136603f77cc16);
#
#
#
#         marker_46fe4cda2b5a72b94a1e1f1ee6dd93c5.bindPopup(popup_0c749ed870488670be1c731c37e32906)
#         ;
#
#
#
#
#             var marker_bf615720fe047b04ab4f5e5469

# %%
facility_color_mapping = {'Hospital':'red', 'Primary Care Center':'blue','Specialized Healthcare Center':'green','Pharmacy':'purple'}

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'][0]])
for index, row in df_geo.iterrows():
    facility_type = row['Facility Type']
    if facility_type in facility_color_mapping:
        color = facility_color_mapping[facility_type]
    else:
        color = 'gray'
    folium.Marker(location=[row['Latitude'],row['Longitude']],popup=row['Facility Type'], icon=folium.Icon(color=color)).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f1a55382f88b5eed8f8e155928b4fbf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f1a55382f88b5eed8f8e155928b4fbf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f1a55382f88b5eed8f8e155928b4fbf = L.map(
#                 &quot;map_6f1a55382f88b5eed8f8e155928b4fbf&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5be40ff241b956cebf9a6e3079fe1dc3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6f1a55382f88b5eed8f8e155928b4fbf);
#
#
#             var marker_91deccca33e0901925e1355f970a6418 = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_6f1a55382f88b5eed8f8e155928b4fbf);
#
#
#             var icon_1c46732709884e591e89554e40488d8c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_91deccca33e0901925e1355f970a6418.setIcon(icon_1c46732709884e591e89554e40488d8c);
#
#
#         var popup_f2d66ef158a5cf13f247d74c1b12e1fd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e2dbd7a172da040fd0d97f4aa3242ba3 = $(`&lt;div id=&quot;html_e2dbd7a172da040fd0d97f4aa3242ba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_f2d66ef158a5cf13f247d74c1b12e1fd.setContent(html_e2dbd7a172da040fd0d97f4aa3242ba3);
#
#
#
#         marker_91deccca33e0901925e1355f970a6418.bindPopup(popup_f2d66ef158a5cf13f247d74c1b12e1fd)
#         ;
#
#
#
#
#             var marker_6803e985e7392e0594d9c63d1e568132 = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_6f1a55382f88b5eed8f8e155928b4fbf);
#
#
#             var icon_aba7fb9cc7251225679eb79eff1899b0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6803e985e7392e0594d9c63d1e568132.setIcon(icon_aba7fb9cc7251225679eb79eff1899b0);
#
#
#         var popup_1c1f8161bd8118bb327acb1228b53893 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c039923d8f962007d50db507ca7e3f74 = $(`&lt;div id=&quot;html_c039923d8f962007d50db507ca7e3f74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_1c1f8161bd8118bb327acb1228b53893.setContent(html_c039923d8f962007d50db507ca7e3f74);
#
#
#
#         marker_6803e985e7392e0594d9c63d1e568132.bindPopup(popup_1c1f8161bd8118bb327acb1228b53893)
#         ;
#
#
#
#
#             var marker_5eaf29aad403c3122976a721c8d38e41 = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_6f1a55382f88b5eed8f8e155928b4fbf);
#
#
#             var icon_49fe4aed0e82c0262040d052576e4f61 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5eaf29aad403c3122976a721c8d38e41.setIcon(icon_49fe4aed0e82c0262040d052576e4f61);
#
#
#         var popup_a12d4b65504db512436d53a30761ce06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3a8ac7c344174a28be2d922dfefda954 = $(`&lt;div id=&quot;html_3a8ac7c344174a28be2d922dfefda954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_a12d4b65504db512436d53a30761ce06.setContent(html_3a8ac7c344174a28be2d922dfefda954);
#
#
#
#         marker_5eaf29aad403c3122976a721c8d38e41.bindPopup(popup_a12d4b65504db512436d53a30761ce06)
#         ;
#
#
#
#
#             var marker_e3fbd34d548c0d805b6e1bd02ecd15f4 = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_6f1a55382f88b5eed8f8e155928b4fbf);
#
#
#             var icon_e5e163d9bd4d39d6fe32a08ec24627a8 = L.AwesomeMarkers.icon(
#                 {&quot;extra

# %% [markdown]
# ##Interactive Map for Public Health Facilities Geolocation Demo Dataset using Folium Part II

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0], df_geo['Longitude'].iloc[0]])
facility_types_to_visualize = ['Hospital']
filtered_df = df_geo[df_geo['Facility Type'].isin(facility_types_to_visualize)]

for index, row in filtered_df.iterrows():
    facility_type = row['Facility Type']
    color = facility_color_mapping.get(facility_type,'gray')
    folium.Marker(location=[row['Latitude'],row['Longitude']], popup=row['Facility Type'], icon=folium.Icon(color=color)).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b7db46d2bfc74fa852ee1391c31b875 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b7db46d2bfc74fa852ee1391c31b875&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b7db46d2bfc74fa852ee1391c31b875 = L.map(
#                 &quot;map_3b7db46d2bfc74fa852ee1391c31b875&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_591ab374305d6ff0f652df215650ac50 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b7db46d2bfc74fa852ee1391c31b875);
#
#
#             var marker_859b3d5b64c314e11ef4adb924fdb4ad = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(map_3b7db46d2bfc74fa852ee1391c31b875);
#
#
#             var icon_150a6854418026f778b235c719678b9f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_859b3d5b64c314e11ef4adb924fdb4ad.setIcon(icon_150a6854418026f778b235c719678b9f);
#
#
#         var popup_b0e0c05b90f0545dfc366da19e59f27e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b0b365775fc55745d3302d3bf6b6950a = $(`&lt;div id=&quot;html_b0b365775fc55745d3302d3bf6b6950a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_b0e0c05b90f0545dfc366da19e59f27e.setContent(html_b0b365775fc55745d3302d3bf6b6950a);
#
#
#
#         marker_859b3d5b64c314e11ef4adb924fdb4ad.bindPopup(popup_b0e0c05b90f0545dfc366da19e59f27e)
#         ;
#
#
#
#
#             var marker_7fd6edca2dad8d1384168484f0773ad4 = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(map_3b7db46d2bfc74fa852ee1391c31b875);
#
#
#             var icon_bb7c95b19032553f11e7c6341ad79ac2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7fd6edca2dad8d1384168484f0773ad4.setIcon(icon_bb7c95b19032553f11e7c6341ad79ac2);
#
#
#         var popup_f32a154c8bd6d32a8519040826d0ec44 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3b1f091f8accf4ee5fea5e9aa88ef09 = $(`&lt;div id=&quot;html_c3b1f091f8accf4ee5fea5e9aa88ef09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_f32a154c8bd6d32a8519040826d0ec44.setContent(html_c3b1f091f8accf4ee5fea5e9aa88ef09);
#
#
#
#         marker_7fd6edca2dad8d1384168484f0773ad4.bindPopup(popup_f32a154c8bd6d32a8519040826d0ec44)
#         ;
#
#
#
#
#             var marker_e1ffc45219493c1e8c2de048253f4ba4 = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(map_3b7db46d2bfc74fa852ee1391c31b875);
#
#
#             var icon_d4cb592cc82fca3fc8024d3e23f4deda = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1ffc45219493c1e8c2de048253f4ba4.setIcon(icon_d4cb592cc82fca3fc8024d3e23f4deda);
#
#
#         var popup_22d61d91ea908e2943ecb246e4300a61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c3bfa66385c4b8e8e76713deccfd5d69 = $(`&lt;div id=&quot;html_c3bfa66385c4b8e8e76713deccfd5d69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_22d61d91ea908e2943ecb246e4300a61.setContent(html_c3bfa66385c4b8e8e76713deccfd5d69);
#
#
#
#         marker_e1ffc45219493c1e8c2de048253f4ba4.bindPopup(popup_22d61d91ea908e2943ecb246e4300a61)
#         ;
#
#
#
#
#             var marker_805f9b1ae0e04adc23d0b1d3b7c99d89 = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(map_3b7db46d2bfc74fa852ee1391c31b875);
#
#
#             var icon_e7aef9f245236a3c5e00ef2da66daad1 = L.AwesomeMarkers.icon(
#                 {&quot;extra

# %% [markdown]
# ##Interactive Map for Public Health Facilities Geolocation Demo Dataset using Folium Part III

# %%
from folium.plugins import HeatMap

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0],df_geo['Longitude'].iloc[0]])

# %%
heat_data = [[row['Latitude'], row['Longitude']] for index, row in df_geo.iterrows()]
HeatMap(heat_data).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7926c3b75cc1cee2dd2b9286b4433fe3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7926c3b75cc1cee2dd2b9286b4433fe3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7926c3b75cc1cee2dd2b9286b4433fe3 = L.map(
#                 &quot;map_7926c3b75cc1cee2dd2b9286b4433fe3&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34a889755a59fe9baeeeaf10f13ef33a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7926c3b75cc1cee2dd2b9286b4433fe3);
#
#
#             var heat_map_6bced2e64d97fd53bfbc00ecbf1b31a7 = L.heatLayer(
#                 [[5.593051172162835, 3.6970074354815217], [10.01756906139408, 9.921846234977282], [7.568807701687042, 11.178650786309912], [11.57456719544622, 12.594134984190545], [6.093634303928882, 9.334974717175706], [4.697225835628155, 10.724419645206533], [6.229633587769467, 8.608930592846766], [7.305192328171373, 8.854772811098668], [12.344506998799671, 13.086979216797712], [5.858643334057811, 6.311904299685715], [9.868023858622411, 14.338512521769582], [10.153403029390656, 4.542435224166499], [9.8994531273852, 7.39682142601457], [10.61172753728869, 11.76155603030724], [13.589522909928212, 4.735938864773079], [5.353375049357906, 5.399552675768428], [8.758567070460828, 9.079422585433376], [12.807394261532163, 11.9539597623729], [7.124467449904785, 3.2068160846506024], [11.39744411449681, 8.086612148889644], [11.851614335063871, 10.443920392921305], [7.529655448280327, 7.983168397777357], [12.46641415266236, 10.842538533477258], [11.35115132772112, 7.819041176386973], [10.003620433983295, 9.14281320005155], [13.340631956096091, 8.069514287018283], [12.34273549474029, 6.869230601337367], [13.732965787149954, 9.672254141796724], [4.672132142151794, 11.715453509182645], [6.853543586417253, 4.695705006955515], [6.156299695455418, 6.855749634780461], [6.246951683067666, 4.359969014933978], [13.510166920575816, 12.006525023061531], [6.473005970718013, 7.197557724054207], [13.398171983455342, 12.861300338409537], [13.247544947832864, 5.525490587301862], [6.750022667687306, 7.380644046659475], [7.438281171649732, 3.4278088136340985], [7.820389424069303, 13.592259704168749], [5.098892382976606, 6.819344947473744], [4.313103005971447, 7.076706614969844], [4.989515835429223, 12.30174402377174], [9.991291953671194, 12.065124157352638], [12.291617069701536, 5.230816379918881], [11.15846465187228, 5.700461133557214], [13.174235094480515, 12.982070698184357], [6.148798370021112, 4.94085441909898], [9.48199075258252, 9.46925857063819], [11.83789870365636, 14.427695922874598], [8.138060071510145, 9.137780525743134], [7.6739393750426546, 3.9264290254797967], [5.737303800403392, 13.041853421193856], [6.377552073568552, 5.865149788991117], [4.536587630598104, 7.7713097288953], [8.176207683341374, 10.81835287739752], [5.311766802884908, 7.865283725798186], [12.99363125187279, 9.042595667074652], [13.840092517423592, 11.042679694425566], [10.676363299906182, 7.1430050839019446], [12.716333796871504, 8.373322360781996], [5.245136197236323, 7.132828159667508], [9.908231946141251, 6.775896690715101], [10.467905212098438, 9.208291154471247], [6.90631942238392, 5.531311603620699], [11.348858833268736, 6.911341680390859], [7.08207003280951, 9.307112036879907], [5.950082175170728, 12.6375751058417], [9.326224606854664, 11.20001115604264], [5.196493610268465, 13.2803805493846], [8.41671549770957, 13.367933788137224], [13.540156903147262, 9.206569621330994], [6.162816483073413, 4.241221269307475], [12.81873862500334, 8.469053884570581], [11.390998639407576, 11.446310836838968], [10.513546453882796, 9.845764982813725], [5.585133172682705, 12.689358187559144], [10.842071566159529, 3.228274984689582], [5.48371960356811, 8.284905001563953], [9.966608723126482, 11.44698069826034], [13.343580089345243, 14.29489000389036], [7.185746660494539, 4.043397625292993], [4.703536991862528, 7.3361407963894365], [8.517000595482168, 7.22599120335442], [5.617474390675247, 10.359712034803882], [4.42123686663982, 10.46798265632879], [8.335644564029135, 9.179645814001086], [8.224219376403905, 5.19362098536938], [13.119690073473336, 10.271873108894791], [7.31872859308945, 13.332661948694913], [13.328176002801357, 11.54212984254263], [8.773502089448758, 12.020778682712589], [5.765238050821395, 8.07520012707431], [6.507080487002569, 11.383911902722623], [6.116183161059648, 8.66013470958954], [6.992811907665175, 8.5499030604087

# %%
m.save('facility_heatmap.html')

# %%
from folium.plugins import MarkerCluster

# %%
m = folium.Map(location=[df_geo['Latitude'].iloc[0],df_geo['Longitude'].iloc[0]])

# %%
marker_cluster = MarkerCluster()

# %%
for index, row in df_geo.iterrows():
    marker = folium.Marker([row['Latitude'],row['Longitude']], popup=row['Facility Type'])
    marker.add_to(marker_cluster)

marker_cluster.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bd8c89361d43b158d54d1b1c332bb39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bd8c89361d43b158d54d1b1c332bb39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bd8c89361d43b158d54d1b1c332bb39 = L.map(
#                 &quot;map_4bd8c89361d43b158d54d1b1c332bb39&quot;,
#                 {
#                     center: [5.593051172162835, 3.6970074354815217],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93805314db74696b3895091ca65c1422 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4bd8c89361d43b158d54d1b1c332bb39);
#
#
#             var marker_cluster_49bf714c28dc7ac9ba8a6257ca73d0bf = L.markerClusterGroup(
#                 {}
#             );
#             map_4bd8c89361d43b158d54d1b1c332bb39.addLayer(marker_cluster_49bf714c28dc7ac9ba8a6257ca73d0bf);
#
#
#             var marker_f808943221b94322380819051b321576 = L.marker(
#                 [5.593051172162835, 3.6970074354815217],
#                 {}
#             ).addTo(marker_cluster_49bf714c28dc7ac9ba8a6257ca73d0bf);
#
#
#         var popup_9d94601e9c7c6db70dfa47163eaae1a4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_97d048be34fd6e4138f6ef8d04c8eb28 = $(`&lt;div id=&quot;html_97d048be34fd6e4138f6ef8d04c8eb28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_9d94601e9c7c6db70dfa47163eaae1a4.setContent(html_97d048be34fd6e4138f6ef8d04c8eb28);
#
#
#
#         marker_f808943221b94322380819051b321576.bindPopup(popup_9d94601e9c7c6db70dfa47163eaae1a4)
#         ;
#
#
#
#
#             var marker_43f6067f2a4aabdd7b1096b691d5d207 = L.marker(
#                 [10.01756906139408, 9.921846234977282],
#                 {}
#             ).addTo(marker_cluster_49bf714c28dc7ac9ba8a6257ca73d0bf);
#
#
#         var popup_ce5c621b1a082a638d9161a8d79307bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8642e2c8668b1e317fed77cbe29d21e6 = $(`&lt;div id=&quot;html_8642e2c8668b1e317fed77cbe29d21e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_ce5c621b1a082a638d9161a8d79307bf.setContent(html_8642e2c8668b1e317fed77cbe29d21e6);
#
#
#
#         marker_43f6067f2a4aabdd7b1096b691d5d207.bindPopup(popup_ce5c621b1a082a638d9161a8d79307bf)
#         ;
#
#
#
#
#             var marker_17a662b3b535ccb30ca13e437c7c6a55 = L.marker(
#                 [7.568807701687042, 11.178650786309912],
#                 {}
#             ).addTo(marker_cluster_49bf714c28dc7ac9ba8a6257ca73d0bf);
#
#
#         var popup_94cabeb319ec305f3180b493c9fb21e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e1bd9d677ada589807337d4e907f3b9 = $(`&lt;div id=&quot;html_1e1bd9d677ada589807337d4e907f3b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_94cabeb319ec305f3180b493c9fb21e5.setContent(html_1e1bd9d677ada589807337d4e907f3b9);
#
#
#
#         marker_17a662b3b535ccb30ca13e437c7c6a55.bindPopup(popup_94cabeb319ec305f3180b493c9fb21e5)
#         ;
#
#
#
#
#             var marker_a0c2cf1c797f03f3f2fe2545b9d2b5d0 = L.marker(
#                 [11.57456719544622, 12.594134984190545],
#                 {}
#             ).addTo(marker_cluster_49bf714c28dc7ac9ba8a6257ca73d0bf);
#
#
#         var popup_d8aa2cf55ee0f8f18c5005b448194c42 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_645fefc8c57d775eecdc77b108d82e7d = $(`&lt;div id=&quot;html_645fefc8c57d775eecdc77b108d82e7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hospital&lt;/div&gt;`)[0];
#                 popup_d8aa2cf55ee0f8f18c5005b448194c42.setContent(html_645fefc8c57d775eecdc77b108d82e7d);
#
#
#
#         marker_a0c2cf1c797f03f3f2fe2545b9d2b5d0.bindPopup(popup_d8aa2cf55ee0f8f18c5005b448194c42)
#         ;
#
#
#
#
#             var marker_808f3198d7e7f9d2195516dc0544a10b = L.marker(
#                 [6.093634303928882, 9.33497471717570
